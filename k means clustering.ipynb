# %% [markdown]
# # K - means clustering
# # Customer Segmentation using K-means Clustering

# %%
#Dataset used - Customer Segmentation 
#IMPORT LIBRARIES

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#reas the data 
df = pd.read_excel("C:\\Users\\manas\\Downloads\\C_S1.xlsx")

# %%
df
# Out:
#      CustomerID  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1   56                  30                      72
# 1             2   69                  83                      92
# 2             3   46                  36                      31
# 3             4   32                 107                       9
# 4             5   60                  90                      51
# ..          ...  ...                 ...                     ...
# 495         496   65                 114                      67
# 496         497   42                  82                      25
# 497         498   57                 147                      98
# 498         499   62                 134                      76
# 499         500   18                  51                      42
#
#      Total Purchase Amount  Number of Transactions  Frequency of Visits  \
# 0                 12237.98                      36                   17
# 1                 10001.01                      69                   23
# 2                  8487.43                      77                    1
# 3                  1761.31                      93                   18
# 4                  6422.57                      31                   20
# ..                     ...                     ...                  ...
# 495                8587.86                      19                   19
# 496               11094.43                      48                   15
# 497                7245.48                      45                   20
# 498                1372.06                      94                   14
# 499                8653.30                      55                   24
#
#      Average Purchase Value
# 0                      9.58
# 1                     70.46
# 2                      1.46
# 3                      3.22
# 4                      0.69
# ..                      ...
# 495                    8.17
# 496                    9.63
# 497                   11.90
# 498                    9.50
# 499                    0.86
#
# [500 rows x 8 columns]

# %%
df.shape
# Out:
# (500, 8)

# %%
df.size
# Out:
# 4000

# %%
df.info
# Out:
# <bound method DataFrame.info of      CustomerID  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1   56                  30                      72
# 1             2   69                  83                      92
# 2             3   46                  36                      31
# 3             4   32                 107                       9
# 4             5   60                  90                      51
# ..          ...  ...                 ...                     ...
# 495         496   65                 114                      67
# 496         497   42                  82                      25
# 497         498   57                 147                      98
# 498         499   62                 134                      76
# 499         500   18                  51                      42
#
#      Total Purchase Amount  Number of Transactions  Frequency of Visits  \
# 0                 12237.98                      36                   17
# 1                 10001.01                      69                   23
# 2                  8487.43                      77                    1
# 3                  1761.31                      93                   18
# 4                  6422.57                      31                   20
# ..                     ...                     ...                  ...
# 495                8587.86                      19                   19
# 496               11094.43                      48                   15
# 497                7245.48                      45                   20
# 498                1372.06                      94                   14
# 499                8653.30                      55                   24
#
#      Average Purchase Value
# 0                      9.58
# 1                     70.46
# 2                      1.46
# 3                      3.22
# 4                      0.69
# ..                      ...
# 495                    8.17
# 496                    9.63
# 497                   11.90
# 498                    9.50
# 499                    0.86
#
# [500 rows x 8 columns]>

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# Total Purchase Amount     0
# Number of Transactions    0
# Frequency of Visits       0
# Average Purchase Value    0
# dtype: int64

# %% [markdown]
# #Exploring the data

# %%
x = df.iloc[:,[3,4]]

# %%
# Create the scatter plot
plt.figure(figsize=(10, 6))
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score (1-100)')
plt.scatter(x.iloc[:, 0], x.iloc[:, 1], color='red', marker='>')
plt.title('Customer Segmentation')
plt.show()

# %% [markdown]
# # Elbow method

# %%
from sklearn. cluster import KMeans

# %%
km = KMeans(random_state=0, n_clusters=5,n_init='auto')

# %%
y =km.fit_predict(x)

# %%
y
# Out:
# array([2, 1, 4, 3, 4, 4, 0, 1, 4, 3, 0, 1, 3, 2, 4, 4, 1, 2, 0, 1, 4, 0,
#        2, 2, 1, 2, 2, 1, 2, 1, 1, 1, 1, 3, 2, 2, 3, 2, 3, 0, 1, 3, 2, 2,
#        4, 3, 0, 1, 2, 1, 0, 1, 4, 1, 3, 1, 4, 2, 0, 1, 2, 3, 2, 1, 3, 0,
#        1, 3, 1, 0, 1, 3, 2, 2, 2, 1, 3, 1, 3, 3, 0, 4, 1, 1, 4, 0, 2, 4,
#        4, 3, 2, 1, 0, 3, 1, 1, 0, 2, 3, 4, 2, 4, 1, 4, 0, 2, 4, 2, 0, 0,
#        3, 1, 0, 2, 4, 2, 0, 2, 1, 1, 2, 1, 1, 3, 3, 2, 1, 2, 4, 3, 3, 1,
#        4, 0, 4, 3, 1, 0, 2, 0, 4, 3, 3, 4, 4, 1, 0, 1, 2, 1, 3, 4, 3, 0,
#        2, 3, 4, 1, 1, 4, 3, 0, 4, 3, 0, 3, 3, 4, 3, 4, 1, 2, 0, 3, 3, 1,
#        1, 3, 2, 3, 4, 1, 2, 1, 2, 0, 2, 3, 2, 4, 2, 4, 1, 4, 1, 3, 3, 0,
#        3, 2, 0, 2, 0, 0, 2, 1, 4, 4, 1, 0, 2, 2, 1, 0, 1, 3, 3, 0, 4, 2,
#        1, 1, 4, 0, 4, 2, 3, 2, 1, 4, 1, 4, 2, 2, 4, 0, 1, 2, 0, 1, 1, 1,
#        3, 1, 2, 0, 0, 2, 0, 2, 4, 0, 2, 4, 4, 0, 1, 3, 4, 2, 0, 1, 0, 1,
#        3, 2, 4, 0, 3, 3, 4, 0, 2, 4, 0, 1, 1, 3, 3, 3, 1, 1, 4, 2, 2, 1,
#        2, 0, 3, 0, 3, 4, 2, 3, 3, 4, 2, 0, 4, 3, 3, 2, 2, 3, 2, 1, 2, 4,
#        4, 4, 1, 3, 3, 0, 1, 0, 1, 2, 3, 1, 4, 2, 0, 1, 2, 2, 1, 4, 1, 2,
#        4, 3, 2, 1, 1, 0, 1, 4, 1, 3, 1, 2, 3, 2, 4, 2, 1, 4, 1, 2, 4, 0,
#        1, 2, 1, 2, 4, 2, 3, 4, 3, 0, 0, 4, 1, 4, 4, 0, 4, 0, 3, 1, 1, 1,
#        4, 4, 2, 4, 4, 3, 0, 4, 4, 1, 4, 1, 1, 2, 1, 2, 3, 0, 3, 1, 2, 0,
#        2, 3, 2, 0, 3, 4, 0, 0, 0, 2, 4, 0, 1, 1, 0, 4, 3, 0, 1, 0, 4, 1,
#        3, 4, 0, 2, 4, 2, 4, 3, 1, 2, 1, 2, 2, 0, 0, 1, 4, 2, 2, 0, 0, 1,
#        0, 2, 4, 1, 3, 1, 4, 1, 3, 1, 2, 0, 3, 3, 1, 1, 4, 0, 4, 1, 4, 2,
#        3, 1, 4, 4, 1, 1, 2, 3, 3, 1, 1, 0, 3, 3, 2, 0, 0, 0, 0, 3, 4, 3,
#        2, 0, 4, 2, 1, 4, 0, 0, 1, 2, 1, 4, 1, 4, 3, 4])

# %%
km.inertia_
# Out:
# 335037574.1537424

# %%
sse = []
for k in range(1, 16):
    km = KMeans(n_clusters=k, random_state=0, n_init='auto')
    km.fit_predict(x)
    sse.append(km.inertia_)

# %%
sse
# Out:
# [8729435355.795408,
#  2186192777.921006,
#  1009159240.4149873,
#  533798071.3872647,
#  335037574.1537424,
#  247024002.70757726,
#  183489373.41898793,
#  147254340.28358132,
#  105591149.22405724,
#  85715418.56716585,
#  68675454.76549904,
#  55050223.70515588,
#  45809225.219353095,
#  40856585.29318721,
#  36558926.148799434]

# %%
cents =km.cluster_centers_

# %%
cents
# Out:
# array([[   53.48571429,  4195.52628571],
#        [   57.86046512,  9761.69      ],
#        [   39.91666667, 13219.20305556],
#        [   41.63414634,  1087.51390244],
#        [   55.15151515,  7758.39818182],
#        [   51.04347826,  6184.06      ],
#        [   55.2173913 , 11480.37782609],
#        [   47.68421053,  2080.59631579],
#        [   53.65789474, 14491.86368421],
#        [   49.17857143,  5317.47607143],
#        [   47.27272727,  8745.44393939],
#        [   45.87804878, 10618.98487805],
#        [   46.15151515,  3219.42090909],
#        [   55.16666667, 12315.924     ],
#        [   57.6       ,  6914.3264    ]])

# %%
plt.figure(figsize=(16,9))
plt.subplot(1,2,1)
plt.title('Unclustered Data')
plt.grid()
plt.xlabel('Annual Income')
plt.ylabel('Spending Income')
plt.scatter(x.iloc[:,0], x.iloc[:,1], color = 'red', marker='>')


plt.subplot(1,2,2)
plt.title('Clustered Data')
plt.grid()
plt.xlabel('Annual Income')
plt.ylabel('Spending Income')
plt.scatter(x.iloc[:,0], x.iloc[:,1], marker='>', c=y)
plt.scatter(cents[:,0], cents[:,1], s=200, color='cyan')

# %% [markdown]
# # Extracting the clusters

# %%
zero = df[y==0]
one = df[y==1]
two = df[y==2]
three = df[y==3]
four = df[y==4]

# %%
print('Cluster-0: ', len(zero))
print('Cluster-1: ', len(one))
print('Cluster-2: ', len(two)) 
print('Cluster-3: ', len(three))
print('Cluster-4: ', len(four))
# Out:
# Cluster-0:  87
# Cluster-1:  121
# Cluster-2:  104
# Cluster-3:  90
# Cluster-4:  98

# %% [markdown]
# # Save the clusters

# %%
zero.to_csv('zero.csv', index=True)

# %% [markdown]
# # Predict the new data

# %%
new = pd.DataFrame([[34,17],[56,10],[104,45],[98,88],[34,17]], columns=x.columns)

# %%
new
# Out:
#    Spending Score (1-100)  Total Purchase Amount
# 0                      34                     17
# 1                      56                     10
# 2                     104                     45
# 3                      98                     88
# 4                      34                     17

# %%
km.predict(new)
# Out:
# array([3, 3, 3, 3, 3])

# %%
x['Cluster'] =y
# Out:
# C:\Users\manas\AppData\Local\Temp\ipykernel_30128\4072497591.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['Cluster'] =y

# %%
x
# Out:
#      Spending Score (1-100)  Total Purchase Amount  Cluster
# 0                        72               12237.98        2
# 1                        92               10001.01        1
# 2                        31                8487.43        4
# 3                         9                1761.31        3
# 4                        51                6422.57        4
# ..                      ...                    ...      ...
# 495                      67                8587.86        4
# 496                      25               11094.43        1
# 497                      98                7245.48        4
# 498                      76                1372.06        3
# 499                      42                8653.30        4
#
# [500 rows x 3 columns]

# %%
sns.jointplot(x = 'Total Purchase Amount', y = 'Spending Score (1-100)',
             data = x, hue='Cluster', palette='tab10')

# %%
sns.jointplot(x = 'Total Purchase Amount', y = 'Spending Score (1-100)',
             data = x, hue='Cluster', palette='tab10')
plt.scatter(cents[:,0], cents[:,1], s=200, color='cyan' , marker='*')

# %%
# !pip install nltk textblob -U
# Out:
# Requirement already satisfied: nltk in c:\users\manas\anaconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: textblob in c:\users\manas\anaconda3\lib\site-packages (0.18.0.post0)
# Requirement already satisfied: click in c:\users\manas\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in c:\users\manas\anaconda3\lib\site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\manas\anaconda3\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\manas\anaconda3\lib\site-packages (from nltk) (4.65.0)
# Requirement already satisfied: colorama in c:\users\manas\anaconda3\lib\site-packages (from click->nltk) (0.4.6)
